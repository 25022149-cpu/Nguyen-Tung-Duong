# %%
#1
n = int(input())
print(2*n)
# Out:
# 10

# %%
#2
a, b = map(int, input().split())
dttron = 3.14*(a/2)**2
dientichcay = a*b - dttron
print(dientichcay)
# Out:
# 4.935

# %%
#3
c = input()
ma = ord(c)
if ma>=97:
    print(chr(ma-32))
elif ma>=65:
    print(chr(ma+32))
# Out:
# a

# %%
#4
c = input()
ma = ord(c)
if (65<=ma<=90) or (97<=ma<=122):
    print(f'{c} là kí tự alphabet')
else:
    print(f'{c} khong phai ki tu alphabet')
# Out:
# a là kí tự alphabet

# %%
#5
c = input()
ma = ord(c)
if c=='A':
    print(f'truong hop dac biet')
else:
    print(f'chu cai lien truoc {c} là {chr(ma+31)}')
# Out:
# chu cai lien truoc d là 

# %%
#6
a, b, c = map(int, input().split())
p = (a+b+c)/2
s = (p*(p-a)*(p-b)*(p-c))**(1/2)
if a+b>c and a+c>b and b+c>a:
    print(s)
else:
    print(f'khong phai 3 canh tam giac')
# Out:
# 6.0

# %%
#7
i = input()
if len(i)>=20:
    print(f'chu cai thu 5 là {i[5]}, chu cai thu chin la {i[9]}')
else:
    print(f'chuoi qua ngan')
# Out:
# chu cai thu 5 là j, chu cai thu chin la h

# %%
#8
a = input()
b = int(input())
c = int(input())
print(f'ten chu ho :{a}')
print(f'chi so thang truoc:{b}')
print(f'chi so thang nay:{c}')

so_dien = c-b
if so_dien <=50:
    print(so_dien*1984*1.08)
if 51<=so_dien<=100:
    print(((so_dien*1984)+(50*2050))*1.08)
if 101<=so_dien<=200:
    print(((so_dien*1984)+(50*2050)+((n-100)*2380))*1.08)
if 201<=so_dien<=300:
    print(((so_dien*1984)+(50*2050)+((100)*2380)+((n-200)*2998))*1.08)
if 301<=so_dien<=400:
    print(((so_dien*1984)+(50*2050)+((100)*2380)+((100)*2998)+((n-300)*3350))*1.08)
if so_dien>=401:
    print(((so_dien*1984)+(50*2050)+((100)*2380)+((100)*2998)+((100)*3350)+(n-400)*3460)*1.08)
# Out:
# ten chu ho :hai
# chi so thang truoc:1020
# chi so thang nay:1070
# 107136.0
