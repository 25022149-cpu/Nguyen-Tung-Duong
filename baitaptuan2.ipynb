# %%
#W2a1
print("Hello World")
# Out:
# Hello World

# %%
#W2A2
name = input()
print(f"Hello {name}")
# Out:
# Hello Dương

# %%
#W2a3
a, b = map(int, input().split())
tong = a+b
hieu = a-b
tich = a*b
nguyen = a//b
du = a%b
chia = a/b
print(tong)
print(hieu)
print(tich)
print(nguyen)
print(du)
print(f"{chia:.2f}")
# Out:
# 13
# 7
# 30
# 3
# 1
# 3.33

# %%
#W2A4
a1, b1, c1, a2, b2, a3 = map(int, input().split())
TB = ((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(TB)
# Out:
# 4.2

# %%
#W2A5
a, b = map(int, input().split())
chia = a/b
print(a, "+" , b, "=", a+b )
print(a, "/", b, "=", f"{chia:.2f}")
# Out:
# 1 + 2 = 3
# 1 / 2 = 0.50

# %%
#W2A6
s = str(input())
a = ord(s)
print(a)
print(chr(a-32))
# Out:
# 97
# A

# %%
#W2A7
A = ((13**2)*3)+5
B = 13**2*3 + 5
print(A, B, sep = "======")
# Out:
# 512======512

# %%
#W2A8
a = float(input())
F = 9/5*a + 32
print(f"{F:.2f}")
# Out:
# 53.60

# %%
#W2A9
a = float(input())
F = a + a*(4/10)+10
print(f'{F:.2f}')
# Out:
# 150.00

# %%
#W2A10
a, b, c = map(str, input().split())
print(f'Hi {c}, {b}, and {a}')
# Out:
# Hi d, c, and a

# %%
#W2A11
h, m = map(int, input().split())
s = h*3600 + m*60
print(f'{h} gio {m} ra {s} giay')
# Out:
# 3 gio 6 ra 11160 giay

# %%
#W2a12
s = int(input())
tong = s*s*6
print(f'{tong} so mieng dan')
# Out:
# 54 so mieng dan

# %%
#w2A13
a = int(input())
b = int(input())
s = a*b
print(s%10)
# Out:
# 2

# %%
#W2A14
a, b = map(int, input().split())
print(f"{b} hoan doi {a}")
# Out:
# 4 hoan doi 3

# %%
#W2A15
n = int(input())
sao = 6*n*(n-1)+1
print(sao)
# Out:
# 121

# %%
#W2A16  
print("spring\nsummer\nfall\nwinter")
# Out:
# spring
# summer
# fall
# winter

# %%
#W2A17
print("*")
print("**")
print("****")
# Out:
# *
# **
# ****

# %%
#W2A18
print("### # #    ### ###")
print(" #  #  #    #   # ")
print(" #  #   #   #   # ")
print(" #  #  #    #   # ")
print(" #  #       #   # ")
# Out:
# ### # #    ### ###
#  #  #  #    #   #
#  #  #   #   #   #
#  #  #  #    #   #
#  #  #       #   #

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
i = "Hello, world"
for j in range(0,10):
    print(i)
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
